# %% [markdown]
# # HSV颜色空间

# %% [markdown]
# # 1. HSV颜色空间

# %% [markdown]
# ① HSV 颜色空间为：
#
# - H - 色调(主波长)。
# - S - 饱和度(纯度/颜色的阴影)。
# - V - 强度。

# %% [markdown]
# # 🌈 OpenCV 基础：HSV 颜色空间深度解析
#
# 作为光电专业的学生，你可以把 **RGB** 理解为“给显示器看的物理叠加”，而把 **HSV** 理解为“给人类大脑看的感官描述”。
#
# ---
#
# ## 一、 什么是 HSV？
# HSV 模型模拟了人类感知颜色的方式，将颜色拆分为三个维度：
#
# * **H (Hue) - 色调**：对应物理上的**主波长**。表示颜色的种类（如红、绿、蓝）。在 OpenCV 中，为了适配 8 位图像，H 的范围被压缩到了 **0-179**。
# * **S (Saturation) - 饱和度**：对应**信号纯度**。表示颜色的深浅或阴影。在 OpenCV 中范围是 **0-255**。
# * **V (Value) - 明度**：对应**光强/照度**。表示颜色的亮度。在 OpenCV 中范围是 **0-255**。
#
#
#
# ---
#
# ## 二、 💡 为什么光电工程首选 HSV？
#
# 在工业视觉（如你关注的智能交通岗位）中，**稳定性（鲁棒性）**至关重要：
#
# 1.  **光照鲁棒性**：如果环境光线变暗，RGB 的三个数值会同时剧烈波动。而在 HSV 空间中，光照变化主要影响 **V (明度)**，而核心特征 **H (色调)** 保持相对稳定。
# 2.  **简化算法**：识别特定颜色（如交通灯、车牌）时，只需锁定 H 的区间，即可排除大部分环境干扰。
#
# ---

# %%
import cv2 #opencv的缩写为cv2
import matplotlib.pyplot as plt # matplotlib库用于绘图展示
import numpy as np   # numpy数值计算工具包

# %%
hsv = cv2.imread('01_Picture/01_cat.jpg', cv2.COLOR_BGR2HSV) 
cv2.imshow('hsv',hsv)
cv2.waitKey(0)
cv2.destroyAllWindows()
